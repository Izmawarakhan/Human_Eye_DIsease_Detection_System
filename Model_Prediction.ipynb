# %%
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
import numpy as np
import os

# %%
model = tf.keras.models.load_model("Trained_eye_disease_model.h5")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3large (Function  (None, 1000)              5507432
#  al)
#
#  dense (Dense)               (None, 4)                 4004
#
# =================================================================
# Total params: 5511436 (21.02 MB)
# Trainable params: 5487036 (20.93 MB)
# Non-trainable params: 24400 (95.31 KB)
# _________________________________________________________________

# %%
image_path="test\DRUSEN\DRUSEN-956663-5.jpeg" 
img = tf.keras.utils.load_img(image_path,target_size=(224,224))
x = tf.keras.utils.img_to_array(img)
x= np.expand_dims(x,axis=0)
x = preprocess_input(x)

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
pred=model.predict(x)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
pred
# Out:
# array([[0.01635454, 0.00221619, 0.97300154, 0.00842766]], dtype=float32)

# %%
class_name = ['CNV','DME','DRUSEN','NORMAL']
result_index = np.argmax(pred)
print("Model Prediction :: ",class_name[result_index])
# Out:
# Model Prediction ::  DRUSEN
